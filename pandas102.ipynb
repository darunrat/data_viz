# %% [markdown]
# <a href="https://colab.research.google.com/github/darunrat/data_viz/blob/main/pandas102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = '/content/drive/My Drive/dataviz_2021'

# %%
covid_file_path = os.path.join(path,'pm-18-jan-2021.csv')
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021/pm-18-jan-2021.csv

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %% [markdown]
# .isnull()??None?

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12418  False          False  ...              False  False
# 12419  False          False  ...              False  False
# 12420  False          False  ...              False  False
# 12421  False          False  ...              False  False
# 12422  False          False  ...              False  False
#
# [12423 rows x 10 columns]

# %% [markdown]
# .any() เอาค่าความจริงในภายในแต่ละ column and มากัน

# %% [markdown]
# .any() เอาค่าความจริงในภายในแต่ละ column OR มากัน

# %%
data_covid.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                       True
# age                       True
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# .all() เอาค่าความจริงในภายในแต่ละ column  มา AND กัน

# %%
data_covid.isnull().all()
# Out:
# No.                      False
# announce_date            False
# notification_date        False
# sex                      False
# age                      False
# nationality              False
# province_of_isolation    False
# province_of_onset        False
# district_of_onset        False
# risk                     False
# dtype: bool

# %%
data_covid.iloc[0,0].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-655f7c695cf3> in <module>()
# ----> 1 data_covid.iloc[0,0].isnull()
#
# AttributeError: 'numpy.int64' object has no attribute 'isnull'

# %%
data_covid['No'][0].isnull()

# %%
data_covid.iloc[0,0]
# Out:
# 1

# %%
data_covid.iloc[:1,0].isnull()
# Out:
# 0    False
# Name: No., dtype: bool

# %% [markdown]
# #ต่อตารางแกน x แกน y
# *  ต่อแกน x คือ เพิ่ม records (เพิ่มจำนวนข้อมูล)
# *   ต่อแกน y คือ เพิ่ม column (เพิ่มรายละเอียดของข้อมูล )

# %% [markdown]
# ##ต่อแกน y pd.concat()

# %%
datakk = data_covid[data_covid['province_of_onset']=='ขอนแก่น']
datakk.head()
# Out:
#        No.  ...                                           risk
# 180    181  ...                                        สนามมวย
# 462    463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466  1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970  1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637  2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
dataUD = data_covid[data_covid['province_of_onset']=='อุดรธานี']
dataUD.head()
# Out:
#      No.  ...                                         risk
# 424  425  ...                                      สนามมวย
# 434  435  ...                                  สถานบันเทิง
# 471  472  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 883  884  ...                                  สถานบันเทิง
# 885  886  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 10 columns]

# %%
datams= data_covid[data_covid['province_of_onset']=='มหาสารคาม']
datams.head()
# Out:
#          No.  ...                                         risk
# 346      347  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 789      790  ...                                  สถานบันเทิง
# 6690    6691  ...                            Cluster สมุทรสาคร
# 10802  10803  ...                            Cluster สมุทรสาคร
#
# [4 rows x 10 columns]

# %%
dataMYisan=pd.concat([datakk,dataUD,datams])
dataMYisan
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
pd.concat([datakk,dataUD,datams], ignore_index=True)
# Out:
#       No.  ...                                           risk
# 0     181  ...                                        สนามมวย
# 1     463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 3    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 5    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 6    5949  ...                              Cluster สมุทรสาคร
# 7    6083  ...                              Cluster สมุทรสาคร
# 8    9334  ...                           อยู่ระหว่างการสอบสวน
# 9    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11  11518  ...                           อยู่ระหว่างการสอบสวน
# 12  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13  11699  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %% [markdown]
# ##ต่อแกน x
#
#
# *  จับ 2 ตารางมาต่อกันเลย
# * เลือกมาเพิ่มเฉพาะบาง column

# %%
data_province =data_covid[['No.','announce_date','province_of_onset']]
data_province
# Out:
#          No. announce_date province_of_onset
# 0          1     1/12/2020     กรุงเทพมหานคร
# 1          2     1/17/2020     กรุงเทพมหานคร
# 2          3     1/22/2020            นครปฐม
# 3          4     1/22/2020     กรุงเทพมหานคร
# 4          5     1/24/2020     กรุงเทพมหานคร
# ...      ...           ...               ...
# 12418  12419     1/18/2021       สมุทรปราการ
# 12419  12420     1/18/2021       สมุทรปราการ
# 12420  12421     1/18/2021            ชลบุรี
# 12421  12422     1/18/2021            ชลบุรี
# 12422  12423     1/18/2021             ระยอง
#
# [12423 rows x 3 columns]

# %%
data_human =data_covid[['No.','age','sex','nationality']]
data_human
# Out:
#          No.   age   sex nationality
# 0          1  61.0  หญิง       China
# 1          2  74.0  หญิง       China
# 2          3  73.0  หญิง    Thailand
# 3          4  68.0   ชาย       China
# 4          5  66.0  หญิง       China
# ...      ...   ...   ...         ...
# 12418  12419  28.0  หญิง    Thailand
# 12419  12420  27.0  หญิง    Thailand
# 12420  12421  10.0   ชาย    Thailand
# 12421  12422  52.0   ชาย    Thailand
# 12422  12423  51.0   ชาย    Thailand
#
# [12423 rows x 4 columns]

# %% [markdown]
# #แบบง่ายรู้ว่า 2 ตาราง record ตรงกัน

# %%
full_table1 =data_human.merge(data_province)
full_table1.head()
# Out:
#    No.   age   sex nationality announce_date province_of_onset
# 0    1  61.0  หญิง       China     1/12/2020     กรุงเทพมหานคร
# 1    2  74.0  หญิง       China     1/17/2020     กรุงเทพมหานคร
# 2    3  73.0  หญิง    Thailand     1/22/2020            นครปฐม
# 3    4  68.0   ชาย       China     1/22/2020     กรุงเทพมหานคร
# 4    5  66.0  หญิง       China     1/24/2020     กรุงเทพมหานคร

# %%
data_human2 =data_human.sort_values('age')
data_human2
# Out:
#          No.   age   sex nationality
# 1987    1988  0.10   ชาย    Thailand
# 6477    6478  0.11  หญิง    Thailand
# 11497  11498  0.11   ชาย       Burma
# 1675    1676  0.30   ชาย       Japan
# 1075    1076  0.40   ชาย    Thailand
# ...      ...   ...   ...         ...
# 12405  12406   NaN   NaN         NaN
# 12406  12407   NaN   NaN         NaN
# 12407  12408   NaN   NaN         NaN
# 12408  12409   NaN   NaN         NaN
# 12409  12410   NaN   NaN         NaN
#
# [12423 rows x 4 columns]

# %%
full_table2 =data_human2.merge(data_province)
full_table2.head()
# Out:
#      No.   age   sex nationality announce_date province_of_onset
# 0   1988  0.10   ชาย    Thailand      4/4/2020             ระยอง
# 1   6478  0.11  หญิง    Thailand    12/30/2020          เพชรบุรี
# 2  11498  0.11   ชาย       Burma     1/16/2021         สมุทรสาคร
# 3   1676  0.30   ชาย       Japan      4/1/2020     กรุงเทพมหานคร
# 4   1076  0.40   ชาย    Thailand     3/27/2020      สุราษฎร์ธานี

# %% [markdown]
# #ต่อแกน x

# %% [markdown]
# ## sort

# %%
data_human2_renamed=data_human2.rename(columns={'No.': 'patientNumber'})
data_human2_renamed.head()
# Out:
#        patientNumber   age   sex nationality
# 1987            1988  0.10   ชาย    Thailand
# 6477            6478  0.11  หญิง    Thailand
# 11497          11498  0.11   ชาย       Burma
# 1675            1676  0.30   ชาย       Japan
# 1075            1076  0.40   ชาย    Thailand

# %%
full_table3 =data_human2_renamed.merge(data_province,left_on='patientNumber',right_on='No.')
full_table3.head()
# Out:
#    patientNumber   age   sex nationality    No. announce_date province_of_onset
# 0           1988  0.10   ชาย    Thailand   1988      4/4/2020             ระยอง
# 1           6478  0.11  หญิง    Thailand   6478    12/30/2020          เพชรบุรี
# 2          11498  0.11   ชาย       Burma  11498     1/16/2021         สมุทรสาคร
# 3           1676  0.30   ชาย       Japan   1676      4/1/2020     กรุงเทพมหานคร
# 4           1076  0.40   ชาย    Thailand   1076     3/27/2020      สุราษฎร์ธานี

# %%
full_table3 =data_human2_renamed.merge(data_covid,how='left',left_on='age',right_on='age')
full_table3.head()
# Out:
#    patientNumber  ...                                         risk
# 0           1988  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1           6478  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2           6478  ...                            Cluster สมุทรสาคร
# 3          11498  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4          11498  ...                            Cluster สมุทรสาคร
#
# [5 rows x 13 columns]

# %% [markdown]
# #map() เลือกมาเฉพาะบาง column

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_human2_renamed['detail'] = data_human2_renamed['patientNumber'].map(data_covid.set_index('No.')['risk'])
data_human2_renamed
# Out:
#        patientNumber  ...                                       detail
# 1987            1988  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 6477            6478  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11497          11498  ...                            Cluster สมุทรสาคร
# 1675            1676  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1075            1076  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...  ...                                          ...
# 12405          12406  ...                            Cluster สมุทรสาคร
# 12406          12407  ...                            Cluster สมุทรสาคร
# 12407          12408  ...                            Cluster สมุทรสาคร
# 12408          12409  ...                            Cluster สมุทรสาคร
# 12409          12410  ...                            Cluster สมุทรสาคร
#
# [12423 rows x 5 columns]

# %% [markdown]
# คุณสมบัติ pandas ก็คือเราสามารถสร้าง column ใหม่ ให้ตาราง df ได้ โดย
#
# ```df['ชื่อ column ใหม่']==list ที่มีจำนวน record ของ df)```

# %%
data_human2_renamed.head()
# Out:
#        patientNumber  ...                                       detail
# 1987            1988  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 6477            6478  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11497          11498  ...                            Cluster สมุทรสาคร
# 1675            1676  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1075            1076  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 5 columns]

# %%
data_human2_renamed['num'] = range(data_human2_renamed.shape[0])
data_human2_renamed
# Out:
#        patientNumber   age  ...                                       detail    num
# 1987            1988  0.10  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      0
# 6477            6478  0.11  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      1
# 11497          11498  0.11  ...                            Cluster สมุทรสาคร      2
# 1675            1676  0.30  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      3
# 1075            1076  0.40  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      4
# ...              ...   ...  ...                                          ...    ...
# 12405          12406   NaN  ...                            Cluster สมุทรสาคร  12418
# 12406          12407   NaN  ...                            Cluster สมุทรสาคร  12419
# 12407          12408   NaN  ...                            Cluster สมุทรสาคร  12420
# 12408          12409   NaN  ...                            Cluster สมุทรสาคร  12421
# ...

# %%
data_human2_renamed['patientNumber'].map(data_covid.set_index('No.')['risk']) #.map มันจะ ผูกค่า 'patientNumber' กับ 'No.' เข้าด้วยกันแล้ว return list ของค่า ['risk']
data_human2_renamed
# Out:
#        patientNumber   age  ...                                       detail    num
# 1987            1988  0.10  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      0
# 6477            6478  0.11  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      1
# 11497          11498  0.11  ...                            Cluster สมุทรสาคร      2
# 1675            1676  0.30  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      3
# 1075            1076  0.40  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      4
# ...              ...   ...  ...                                          ...    ...
# 12405          12406   NaN  ...                            Cluster สมุทรสาคร  12418
# 12406          12407   NaN  ...                            Cluster สมุทรสาคร  12419
# 12407          12408   NaN  ...                            Cluster สมุทรสาคร  12420
# 12408          12409   NaN  ...                            Cluster สมุทรสาคร  12421
# ...

# %% [markdown]
# ##Hw7 สร้างตารางใหม่ ที่ค่าใน```sex``` เป็น  missing ทั้งหมด
# -  สรุปว่าทำไม record นั้นๆถึงเป็น missing

# %%
data_covid
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12418  12419  ...                                  สถานบันเทิง
# 12419  12420  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12420  12421  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12421  12422  ...                  Cluster ชลบุรี โรงเบียร์ 90
# 12422  12423  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12423 rows x 10 columns]

# %%
update_sex =data_covid.fillna(value={'sex':'missing'})
update_sex.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
update_2 = update_sex[update_sex['sex']=='missing']
update_2
# Out:
#          No. announce_date  ... district_of_onset               risk
# 4391    4392    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4392    4393    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4393    4394    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4394    4395    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4395    4396    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# ...      ...           ...  ...               ...                ...
# 12405  12406     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12406  12407     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12407  12408     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12408  12409     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12409  12410     1/18/2021  ...               NaN  Cluster สมุทรสาคร
#
# [2497 rows x 10 columns]

# %%
update_2.shape
# Out:
# (2497, 10)

# %% [markdown]
# ##### **มี missing ที่ไม่ทราบ sex ทั้งหมด 2497 คน**

# %%
modeprovince=update_2.iloc[: ,3:10]

# %%
update_2.iloc[: ,3:10]
# Out:
#            sex  age  ... district_of_onset               risk
# 4391   missing  NaN  ...             เมือง  Cluster สมุทรสาคร
# 4392   missing  NaN  ...             เมือง  Cluster สมุทรสาคร
# 4393   missing  NaN  ...             เมือง  Cluster สมุทรสาคร
# 4394   missing  NaN  ...             เมือง  Cluster สมุทรสาคร
# 4395   missing  NaN  ...             เมือง  Cluster สมุทรสาคร
# ...        ...  ...  ...               ...                ...
# 12405  missing  NaN  ...               NaN  Cluster สมุทรสาคร
# 12406  missing  NaN  ...               NaN  Cluster สมุทรสาคร
# 12407  missing  NaN  ...               NaN  Cluster สมุทรสาคร
# 12408  missing  NaN  ...               NaN  Cluster สมุทรสาคร
# 12409  missing  NaN  ...               NaN  Cluster สมุทรสาคร
#
# [2497 rows x 7 columns]

# %%
modeprovince=update_2.iloc[: ,5]
modeprovince1=update_2.iloc[: ,6]
modeprovince2=update_2.iloc[: ,7]
modeprovince3=update_2.iloc[: ,8]
modeprovince4=update_2.iloc[: ,9]

# %%
import statistics as st

# %%
mode = st.mode(modeprovince)
print(mode)
mode1 = st.mode(modeprovince1)
print(mode1)
mode2 = st.mode(modeprovince2)
print(mode2)
mode3 = st.mode(modeprovince3)
print(mode3)
mode4 = st.mode(modeprovince4)
print(mode4)
# Out:
# Burma
# สมุทรสาคร
# สมุทรสาคร
# เมือง
# Cluster สมุทรสาคร

# %%
print(f'ค่า sex เป็น missing พบ \n nationality คือ {mode} \n Province_of_isolution คือ {mode1} \n Province_of_onset คือ {mode2} \n district_of_onset คือ {mode3} \n risk คือ {mode4}\n')
# Out:
# ค่า sex เป็น missing พบ
#  nationality คือ Burma
#  Province_of_isolution คือ สมุทรสาคร
#  Province_of_onset คือ สมุทรสาคร
#  district_of_onset คือ เมือง
#  risk คือ Cluster สมุทรสาคร

# %%
update_6=update_2['nationality']
update_6[update_2['nationality']=='Burma'].shape
a=update_6[update_2['nationality']=='Burma'].shape

# %%
update_5=update_2['province_of_isolation']
update_5[update_2['province_of_isolation']=='สมุทรสาคร'].shape
b=update_5[update_2['province_of_isolation']=='สมุทรสาคร'].shape

# %%
update_3=update_2['province_of_onset']
update_3[update_2['province_of_onset']=='สมุทรสาคร'].shape
c=update_3[update_2['province_of_onset']=='สมุทรสาคร'].shape

# %%
update_4=update_2['district_of_onset']
update_4[update_2['district_of_onset']=='เมือง'].shape
d=update_4[update_2['district_of_onset']=='เมือง'].shape

# %%
update_7=update_2['risk']
update_7[update_2['risk']=='Cluster สมุทรสาคร'].shape
e=update_7[update_2['risk']=='Cluster สมุทรสาคร'].shape

# %%
print(f'ค่า sex เป็น missing พบ \n nationality คือ Burma = {a} คน  \n Province_of_isolution คือ  สมุทรสาคร = {b} คน \n Province_of_onset คือ สมุทรสาคร = {c} คน \n district_of_onset คือ สมุทรสาคร= {d} คน \n risk คือCluster สมุทรสาคร = {e} คน \n')
# Out:
# ค่า sex เป็น missing พบ
#  nationality คือ Burma = (1366,) คน
#  Province_of_isolution คือ  สมุทรสาคร = (2308,) คน
#  Province_of_onset คือ สมุทรสาคร = (1353,) คน
#  district_of_onset คือ สมุทรสาคร= (1352,) คน
#  risk คือCluster สมุทรสาคร = (2253,) คน

# %% [markdown]
# #####**สรุป ที่ค่าในตารางมีค่าเป็น missing เนื่องจาก เป็นข้อมูลที่ไม่มีการจดบันทึกค่าลงหรือไม่ทราบข้อมูล**

# %% [markdown]
# * .groupby
# *   create pandas table

# %% [markdown]
# ## .groupby()
#
# https://www.kaggle.com/crawford/python-groupby-tutorial

# %%
data_covid.groupby('nationality').count() #จัดกลุ่มค่าที่เหมือนกันไว้ด้วยกัน
# Out:
#                 No.  announce_date  ...  district_of_onset  risk
# nationality                         ...
# Afghanistan       1              1  ...                  1     1
# Albania           3              3  ...                  2     3
# American          1              1  ...                  1     1
# American          1              1  ...                  1     1
# American Samoa    1              1  ...                  1     1
# ...             ...            ...  ...                ...   ...
# deutsch           1              1  ...                  1     1
# thailand          2              2  ...                  2     2
# ต่างด้าว         21             21  ...                 21    21
# ไทยใหญ่           1              1  ...                  1     1
# ไทใหญ่            1              1  ...                  1     1
#
# [100 rows x 9 columns]

# %%
data_covid.groupby('nationality').mean()
# Out:
#                          No.        age
# nationality
# Afghanistan      4346.000000  31.000000
# Albania          2377.333333  40.666667
# American         3862.000000  39.000000
# American         3905.000000  46.000000
# American Samoa  11687.000000  21.000000
# ...                      ...        ...
# deutsch          3898.000000  55.000000
# thailand         6823.000000  53.500000
# ต่างด้าว         2944.952381  20.000000
# ไทยใหญ่         10379.000000  30.000000
# ไทใหญ่           5983.000000  33.000000
#
# [100 rows x 2 columns]

# %%
data_covid.groupby('nationality').max(' ')
# Out:
#                   No.   age
# nationality
# Afghanistan      4346  31.0
# Albania          3522  51.0
# American         3862  39.0
# American         3905  46.0
# American Samoa  11687  21.0
# ...               ...   ...
# deutsch          3898  55.0
# thailand         6824  57.0
# ต่างด้าว         2998  43.0
# ไทยใหญ่         10379  30.0
# ไทใหญ่           5983  33.0
#
# [100 rows x 2 columns]

# %%
data_covid.dtypes
# Out:
# No.                        int64
# announce_date             object
# notification_date         object
# sex                       object
# age                      float64
# nationality               object
# province_of_isolation     object
# province_of_onset         object
# district_of_onset         object
# risk                      object
# dtype: object

# %% [markdown]
# ทำ Hw7 ด้วย groupby()

# %%
data_covid['sex'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12418    False
# 12419    False
# 12420    False
# 12421    False
# 12422    False
# Name: sex, Length: 12423, dtype: bool

# %%
missing_sex = data_covid[data_covid['sex'].isnull()]
missing_sex
# Out:
#          No. announce_date  ... district_of_onset               risk
# 4391    4392    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4392    4393    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4393    4394    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4394    4395    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4395    4396    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# ...      ...           ...  ...               ...                ...
# 12405  12406     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12406  12407     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12407  12408     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12408  12409     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12409  12410     1/18/2021  ...               NaN  Cluster สมุทรสาคร
#
# [2497 rows x 10 columns]

# %%
missing_sex.groupby('nationality').describe()
# Out:
#                 No.                                   ...   age
#               count         mean         std     min  ...   25%   50%   75%   max
# nationality                                           ...
# Burma        1366.0  5124.517570  472.244857  4392.0  ...   NaN   NaN   NaN   NaN
# Cambodia       61.0  6861.278689  275.220828  6543.0  ...   NaN   NaN   NaN   NaN
# Thailand       46.0  7295.500000  402.917017  6272.0  ...  28.0  28.0  28.0  28.0
#
# [3 rows x 16 columns]

# %%
missing_sex.groupby('province_of_onset').describe()
# Out:
#                       No.                           ...   age
#                     count         mean         std  ...   50%   75%   max
# province_of_onset                                   ...
# ชลบุรี               18.0  7506.055556    6.637436  ...  28.0  28.0  28.0
# ระยอง                 6.0  6289.000000   49.010203  ...   NaN   NaN   NaN
# สมุทรสาคร          1353.0  5108.699926  448.936818  ...   NaN   NaN   NaN
#
# [3 rows x 16 columns]

# %%
missing_sex.groupby(['province_of_onset','nationality']).describe()
# Out:
#                                   No.               ...   age
#                                 count         mean  ...   75%   max
# province_of_onset nationality                       ...
# ชลบุรี            Thailand       18.0  7506.055556  ...  28.0  28.0
# ระยอง             Thailand        1.0  6389.000000  ...   NaN   NaN
# สมุทรสาคร         Thailand        3.0  6273.000000  ...   NaN   NaN
#                   Burma        1349.0  5103.564122  ...   NaN   NaN
#
# [4 rows x 16 columns]

# %%
missing_sex_no_burma =missing_sex[missing_sex['nationality']!='Burma']
missing_sex_no_burma
# Out:
#          No. announce_date  ... district_of_onset               risk
# 6123    6124    12/27/2020  ...               NaN  Cluster สมุทรสาคร
# 6124    6125    12/27/2020  ...               NaN  Cluster สมุทรสาคร
# 6125    6126    12/27/2020  ...               NaN  Cluster สมุทรสาคร
# 6126    6127    12/27/2020  ...               NaN  Cluster สมุทรสาคร
# 6127    6128    12/27/2020  ...               NaN  Cluster สมุทรสาคร
# ...      ...           ...  ...               ...                ...
# 12405  12406     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12406  12407     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12407  12408     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12408  12409     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12409  12410     1/18/2021  ...               NaN  Cluster สมุทรสาคร
#
# [1131 rows x 10 columns]

# %%
missing_sex_no_burma =missing_sex[missing_sex['nationality']!='Burma']
missing_sex_no_burma.groupby('risk').describe()
# Out:
#                         No.                             ...   age
#                       count          mean          std  ...   50%   75%   max
# risk                                                    ...
# Cluster ชลบุรี         18.0   7506.055556     6.637436  ...  28.0  28.0  28.0
# Cluster ระยอง           7.0   6363.285714   201.569437  ...   NaN   NaN   NaN
# Cluster สมุทรสาคร     890.0  11417.015730  1231.866699  ...   NaN   NaN   NaN
# อยู่ระหว่างการสอบสวน   72.0   6854.111111   269.187068  ...   NaN   NaN   NaN
#
# [4 rows x 16 columns]

# %%
missing_sex.groupby('risk').describe()
# Out:
#                          No.                            ...   age
#                        count         mean          std  ...   50%   75%   max
# risk                                                    ...
# Cluster ชลบุรี          18.0  7506.055556     6.637436  ...  28.0  28.0  28.0
# Cluster ระยอง            8.0  6452.250000   313.277946  ...   NaN   NaN   NaN
# Cluster สมุทรสาคร     2253.0  7607.873058  3195.070787  ...   NaN   NaN   NaN
# อยู่ระหว่างการสอบสวน    74.0  6852.945946   269.058169  ...   NaN   NaN   NaN
#
# [4 rows x 16 columns]

# %%
missing_sex[missing_sex['risk']=='Cluster สมุทรสาคร']
# Out:
#          No. announce_date  ... district_of_onset               risk
# 4391    4392    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4392    4393    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4393    4394    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4394    4395    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4395    4396    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# ...      ...           ...  ...               ...                ...
# 12405  12406     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12406  12407     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12407  12408     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12408  12409     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12409  12410     1/18/2021  ...               NaN  Cluster สมุทรสาคร
#
# [2253 rows x 10 columns]

# %%
missing_sex[missing_sex['risk']=='Cluster สมุทรสาคร'].groupby('announce_date').count()
# Out:
#                No.  notification_date  ...  district_of_onset  risk
# announce_date                          ...
# 1/14/2021      172                172  ...                  0   172
# 1/17/2021      311                311  ...                  0   311
# 1/18/2021      269                269  ...                  0   269
# 1/5/2021         4                  4  ...                  1     4
# 1/7/2021       109                109  ...                  0   109
# 12/20/2020     516                  0  ...                516   516
# 12/21/2020     360                  0  ...                360   360
# 12/22/2020     397                  0  ...                397   397
# 12/25/2020      35                  0  ...                 35    35
# 12/26/2020      12                  0  ...                 12    12
# 12/27/2020      36                 18  ...                 18    36
# 12/28/2020      14                  0  ...                 14    14
# ...

# %% [markdown]
# ## create pandas table

# %% [markdown]
# ![pandas-dataframe-shadow.png](data:image/png;base64,...)

# %%
records =[{'account':'Jones llc','Jan':150,'Feb':200,'Mar':140},
               {'account':'Alpha co ','Jan':200,'Feb':210,'Mar':215},
               {'account':'Bule Inc ','Jan':50,'Feb':90,'Mar':95}]
records_df = pd.DataFrame(records)
records_df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones llc  150  200  140
# 1  Alpha co   200  210  215
# 2  Bule Inc    50   90   95

# %% [markdown]
# # Simple Visualizion

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.groupby('Name').count()
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth
# Name
# Iris-setosa               50          50           50          50
# Iris-versicolor           50          50           50          50
# Iris-virginica            50          50           50          50

# %%
pd.plotting.parallel_coordinates(df, 'Name')

# %%
pd.plotting.scatter_matrix(df); #ใส่ ; เพื่อลบข้อมูลที่เป็นตัวอักษรออก

# %% [markdown]
# # Save table

# %%
announce_date_count = missing_sex[missing_sex['risk']== 'Cluster สมุทรสาคร'].groupby('announce_date').count()
announce_date_count
# Out:
#                No.  notification_date  ...  district_of_onset  risk
# announce_date                          ...
# 1/14/2021      172                172  ...                  0   172
# 1/17/2021      311                311  ...                  0   311
# 1/18/2021      269                269  ...                  0   269
# 1/5/2021         4                  4  ...                  1     4
# 1/7/2021       109                109  ...                  0   109
# 12/20/2020     516                  0  ...                516   516
# 12/21/2020     360                  0  ...                360   360
# 12/22/2020     397                  0  ...                397   397
# 12/25/2020      35                  0  ...                 35    35
# 12/26/2020      12                  0  ...                 12    12
# 12/27/2020      36                 18  ...                 18    36
# 12/28/2020      14                  0  ...                 14    14
# ...

# %%
announce_date_count.to_csv('announce_date_count.csv')
