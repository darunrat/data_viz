# %% [markdown]
# <a href="https://colab.research.google.com/github/darunrat/data_viz/blob/main/Midterm2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = '/content/drive/My Drive/midterm2021'

# %%
renamed_file_path = os.path.join(path,'คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx')
print(renamed_file_path)
# Out:
# /content/drive/My Drive/midterm2021/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx

# %%
renamed1_file_path = os.path.join(path,'คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx')
print(renamed1_file_path)
# Out:
# /content/drive/My Drive/midterm2021/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx

# %%
renamed2_file_path = os.path.join(path,'Project1-StuList-1-63-ตัดเกรด_renamed.xlsx')
print(renamed2_file_path)
# Out:
# /content/drive/My Drive/midterm2021/Project1-StuList-1-63-ตัดเกรด_renamed.xlsx

# %%
a = path + '/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx'
print(a)
# Out:
# /content/drive/My Drive/midterm2021/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx

# %%
 renamed = pd.read_excel(renamed_file_path,sheet_name=0,skiprows=1) #คะแนนสอบปากเปล่า
 renamed
# Out:
#       ห้องสอบ              เวลา  ... ความถูกต้องของเนื้อหาในเล่มรายงาน รวม
# 0         NaN               NaN  ...                                10  70
# 1     SC 6501  08:00 – 10.00 น.  ...                                 6  52
# 2         NaN               NaN  ...                                 6  50
# 3         NaN               NaN  ...                                 8  60
# 4         NaN               NaN  ...                                 8  58
# 5         NaN  10:00 – 12.00 น.  ...                                 7  52
# 6         NaN               NaN  ...                                 7  52
# 7         NaN               NaN  ...                                 7  48
# 8         NaN               NaN  ...                                 7  48
# 9   SC 6502\n  08:00 – 10.00 น.  ...                                 6  53
# 10        NaN               NaN  ...                                 6  53
# ...

# %%
 renamed = pd.read_excel(renamed_file_path,sheet_name=0,skiprows=1) 
 renamed.head()
# Out:
#    ห้องสอบ              เวลา  ... ความถูกต้องของเนื้อหาในเล่มรายงาน รวม
# 0      NaN               NaN  ...                                10  70
# 1  SC 6501  08:00 – 10.00 น.  ...                                 6  52
# 2      NaN               NaN  ...                                 6  50
# 3      NaN               NaN  ...                                 8  60
# 4      NaN               NaN  ...                                 8  58
#
# [5 rows x 13 columns]

# %%
 renamed = pd.read_excel(renamed_file_path,sheet_name=0,skiprows=1) 
 renamed.shape
# Out:
# (55, 13)

# %%
renamed_1 = renamed.fillna(method='ffill')
renamed_1.head()
# Out:
#    ห้องสอบ              เวลา  ... ความถูกต้องของเนื้อหาในเล่มรายงาน รวม
# 0      NaN               NaN  ...                                10  70
# 1  SC 6501  08:00 – 10.00 น.  ...                                 6  52
# 2  SC 6501  08:00 – 10.00 น.  ...                                 6  50
# 3  SC 6501  08:00 – 10.00 น.  ...                                 8  60
# 4  SC 6501  08:00 – 10.00 น.  ...                                 8  58
#
# [5 rows x 13 columns]

# %% [markdown]
# อาจาร์ยแต่ล่ะคนที่เป็นที่ปรึกษา

# %%
renamed_name=renamed['นักศึกษา']
renamed_name[renamed['อาจารย์']=='ดร.ธิปไตย']
# Out:
# 1    leaky-rust-chameleon
# 5     wiggy-silver-drever
# Name: นักศึกษา, dtype: object

# %%
renamed_name[renamed['อาจารย์']=='รศ.ธิดาเดียว']
# Out:
# 9             paltry-plum-saola
# 13    gloppy-persimmon-flamingo
# 17           sickly-grey-dugong
# Name: นักศึกษา, dtype: object

# %%
renamed_name[renamed['อาจารย์']=='ผศ.สุกัญญา']
# Out:
# 21    whiny-pear-otter
# Name: นักศึกษา, dtype: object

# %%
renamed_name[renamed['อาจารย์']=='ดร.ธนพงศ์']
# Out:
# 25     jumpy-apricot-frise
# 29    hasty-magnolia-devil
# 35      randy-gamboge-blue
# Name: นักศึกษา, dtype: object

# %%
renamed_name[renamed['อาจารย์']=='ผศ.วุฒิชัย']
# Out:
# 33    lumpy-carmine-slug
# Name: นักศึกษา, dtype: object

# %%
renamed_name[renamed['อาจารย์']=='รศ.สุพรรณี']
# Out:
# 39    chewy-persimmon-catfish
# 43     greasy-eggplant-oyster
# 47           hazy-beige-stoat
# Name: นักศึกษา, dtype: object

# %%
renamed_name[renamed['อาจารย์']=='อ.ยุภาพร']
# Out:
# 51    nerdy-plum-abyssinian
# Name: นักศึกษา, dtype: object

# %%
ads_1=renamed['รวม']
ads_2=ads_1[renamed['นักศึกษา']=='leaky-rust-chameleon']
ads_3=ads_1[renamed['นักศึกษา']=='greasy-ruby-bombay']
ads_4=ads_1[renamed['นักศึกษา']=='wiggy-silver-drever']
ads_5=ads_1[renamed['นักศึกษา']=='stinky-red-chow']
ads_6=ads_1[renamed['นักศึกษา']=='bumpy-indigo-dolphin']
ads_7=ads_1[renamed['นักศึกษา']=='randy-rust-lionfish']
ads_8=ads_1[renamed['นักศึกษา']=='flaky-sepia-setter']
ads_9=ads_1[renamed['นักศึกษา']=='pasty-tomato-okapi']

# %% [markdown]
# รวมคะแนนของแต่ล่ะคน แล้วจะได้คะแนนออกมา คนล่ะ2ช่อง  เอาคะแนนมาบวกกันแล้วเอาไปใส่ตาราง

# %%
for i in (ads_2,ads_6,ads_3,ads_4,ads_5,ads_7,ads_8,ads_9):
  m1=(ads_2*30)/70
  print(m1)
  m2=(ads_3*30)/70  
  print(m2)
  m3=(ads_4*30)/70
  print(m3)
  m4=(ads_5*30)/70
  print(m4) 
  m5=(ads_6*30)/70
  print(m5)
  m6=(ads_7*30)/70
  print(m6)
  m7=(ads_8*30)/70 
  print(m7)
  m8=(ads_9*30)/70
  print(m8)
# Out:
# 1    22.285714
# 3    25.714286
# Name: รวม, dtype: float64
# 2    21.428571
# 4    24.857143
# Name: รวม, dtype: float64
# 5    22.285714
# 7    20.571429
# Name: รวม, dtype: float64
# 6    22.285714
# 8    20.571429
# Name: รวม, dtype: float64
# Series([], Name: รวม, dtype: float64)
# Series([], Name: รวม, dtype: float64)
# Series([], Name: รวม, dtype: float64)
# Series([], Name: รวม, dtype: float64)
# 1    22.285714
# 3    25.714286
# Name: รวม, dtype: float64
# 2    21.428571
# 4    24.857143
# Name: รวม, dtype: float64
# 5    22.285714
# 7    20.571429
# Name: รวม, dtype: float64
# 6    22.285714
# 8    20.571429
# Name: รวม, dtype: float64
# Series([], Name: รวม, dtype: float64)
# Series([], Name: รวม, dtype: float64)
# Series([], Name: รวม, dtype: float64)
# Series([], Name: รวม, dtype: float64)
# 1    22.285714
# 3    25.714286
# Name: รวม, dtype: float64
# 2    21.428571
# 4    24.857143
# Name: รวม, dtype: float64
# 5    22.285714
# 7    20.571429
# ...

# %% [markdown]
# A. ปรับ Z-score ของคะแนนของกรรมการสอบแต่ละท่าน (ไฟล์ คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx)

# %% [markdown]
# B.นำ Z-score จากข้อ 1. มาเข้าสูตร

# %%
def cal_adjusted_score(z_score):
    return round(30 + ((-15*(z_score-2.3103448275862064))/(-4.788052880847054)),2)

# %%
 advisor = pd.read_excel(renamed1_file_path,sheet_name=0,skiprows=1) #คะแนนอาจารย์ที่ปรึกษา
 advisor
# Out:
#              Unnamed: 0  ...                                        Unnamed: 12
# 0                   NaN  ...                                                NaN
# 1  leaky-rust-chameleon  ...  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# 2    greasy-ruby-bombay  ...                                                NaN
# 3   wiggy-silver-drever  ...  2.การศึกษาการทำประกันภัยพืชผลจากภัยแล้งโดยใช้ค...
# 4       stinky-red-chow  ...                                                NaN
# 5  bumpy-indigo-dolphin  ...  23.การศึกษาการทำประกันภัยพืชผลจากภัยแล้งโดยใช้...
# 6   randy-rust-lionfish  ...                                                NaN
# 7    flaky-sepia-setter  ...  32.ความเสี่ยงทางไซเบอร์ในองค์กรที่มีสาเหตุมาจา...
# 8    pasty-tomato-okapi  ...                                                NaN
#
# [9 rows x 13 columns]

# %%
 classroom = pd.read_excel(renamed2_file_path,sheet_name=0,skiprows=1) #คะแนนในห้องเรียน
classroom
# Out:
#     Unnamed: 0   Unnamed: 1  ... Unnamed: 23 Unnamed: 24
# 0            1  603020450-3  ...       จำนวน      ร้อยละ
# 1            2  603020451-1  ...           0           0
# 2            3  603020452-9  ...           0           0
# 3            4  603020453-7  ...           0           0
# 4            5  603020458-7  ...           0           0
# ..         ...          ...  ...         ...         ...
# 83          84  603021885-3  ...         NaN         NaN
# 84          85  603021886-1  ...         NaN         NaN
# 85          86  603021888-7  ...         NaN         NaN
# 86          87  603021889-5  ...         NaN         NaN
# 87          88          NaN  ...         NaN         NaN
#
# [88 rows x 25 columns]

# %%
advisor['Unnamed: 0']
# Out:
# 0                     NaN
# 1    leaky-rust-chameleon
# 2      greasy-ruby-bombay
# 3     wiggy-silver-drever
# 4         stinky-red-chow
# 5    bumpy-indigo-dolphin
# 6     randy-rust-lionfish
# 7      flaky-sepia-setter
# 8      pasty-tomato-okapi
# Name: Unnamed: 0, dtype: object

# %% [markdown]
# รวมคะแนนในห้องเรียนของนักศึกษา 8 คน

# %%
classroom['Unnamed: 2']=='randy-rust-lionfish'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# Name: Unnamed: 2, Length: 88, dtype: bool

# %%
classroom['Unnamed: 2']=='pasty-tomato-okapi'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# Name: Unnamed: 2, Length: 88, dtype: bool

# %%
a=classroom.iloc[: ,9] #คะแนนในห้องเรียน
a1=a[classroom['Unnamed: 2']=='leaky-rust-chameleon']
a2=a[classroom['Unnamed: 2']=='greasy-ruby-bombay']
a3=a[classroom['Unnamed: 2']=='wiggy-silver-drever']
a4=a[classroom['Unnamed: 2']=='stinky-red-chow']
a5=a[classroom['Unnamed: 2']=='bumpy-indigo-dolphin']
a6=a[classroom['Unnamed: 2']=='randy-rust-lionfish']
a7=a[classroom['Unnamed: 2']=='flaky-sepia-setter']
a8=a[classroom['Unnamed: 2']=='pasty-tomato-okapi']

# %%
b=classroom[' Total 5%']
b1=b[classroom['Unnamed: 2']=='leaky-rust-chameleon']
b2=b[classroom['Unnamed: 2']=='greasy-ruby-bombay']
b3=b[classroom['Unnamed: 2']=='wiggy-silver-drever']
b4=b[classroom['Unnamed: 2']=='stinky-red-chow']
b5=b[classroom['Unnamed: 2']=='bumpy-indigo-dolphin']
b6=b[classroom['Unnamed: 2']=='randy-rust-lionfish']
b7=b[classroom['Unnamed: 2']=='flaky-sepia-setter']
b8=b[classroom['Unnamed: 2']=='pasty-tomato-okapi']

# %%
print(a1+b1)
print(a2+b2)
print(a3+b3)
print(a4+b4)
print(a5+b5)
print(a6+b6)
print(a7+b7)
print(a8+b8)

#
# Out:
# 1    9.375
# dtype: object
# 28    9.375
# dtype: object
# 74    10
# dtype: object
# 75    10
# dtype: object
# 51    10
# dtype: object
# Series([], dtype: object)
# 50    10
# dtype: object
# Series([], dtype: object)

# %%
d = [{'advisor':'ดร.ธิปไตย','name':'leaky-rust-chameleon','adv_score': ' ' ,'pres_score':' ','class_score':9.375},
     {'advisor':'ดร.ธิปไตย','name':'greasy-ruby-bombayr','adv_score':' ','pres_score':' ','class_score':9.375 },
     {'advisor':'ดร.ธิปไตย','name':'wiggy-silver-drever','adv_score':' ','pres_score':' ','class_score':10},
     {'advisor':'ดร.ธิปไตย','name':'stinky-red-chow','adv_score':' ','pres_score':' ','class_score':10},
     {'advisor':' ','name':'bumpy-indigo-dolphin','adv_score':' ','pres_score':' ','class_score':10},
     {'advisor':' ','name':'randy-rust-lionfish','adv_score':' ','pres_score':' ','class_score': ' '},
     {'advisor':' ','name':'flaky-sepia-setter','adv_score':' ','pres_score':' ','class_score':10},
     {'advisor':' ','name':'pasty-tomato-okapi','adv_score':' ','pres_score':' ','class_score': ' '}]
this = pd.DataFrame(d)
this
# Out:
#      advisor                  name adv_score pres_score class_score
# 0  ดร.ธิปไตย  leaky-rust-chameleon                            9.375
# 1  ดร.ธิปไตย   greasy-ruby-bombayr                            9.375
# 2  ดร.ธิปไตย   wiggy-silver-drever                               10
# 3  ดร.ธิปไตย       stinky-red-chow                               10
# 4             bumpy-indigo-dolphin                               10
# 5              randy-rust-lionfish
# 6               flaky-sepia-setter                               10
# 7               pasty-tomato-okapi

# %% [markdown]
# ไม่เจอรายชื่อ randy-rust-lionfish และ pasty-tomato-okapi ในห้องเรียน

# %% [markdown]
# รวมคะแนนอาจารย์ที่ปรึกษา คะแนนสอบปากเปล่า และคะแนนเข้าชั้นเรียน

# %%
pd.plotting.parallel_coordinates(this,'advisor',cols=['adv_score','pres_score','class_score']);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-272-7d7f0248aa78> in <module>()
# ----> 1 pd.plotting.parallel_coordinates(this,'advisor',cols=['adv_score','pres_score','class_score']);
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_misc.py in parallel_coordinates(frame, class_column, cols, ax, color, use_columns, xticks, colormap, axvlines, axvlines_kwds, sort_labels, **kwargs)
#     407         axvlines_kwds=axvlines_kwds,
#     408         sort_labels=sort_labels,
# --> 409         **kwargs,
#     410     )
#     411
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/misc.py in parallel_coordinates(frame, class_column, cols, ax, color, use_columns, xticks, colormap, axvlines, axvlines_kwds, sort_labels, **kwds)
#     370         if label not in used_legends:
#     371             used_legends.add(label)
# ...

# %% [markdown]
# เมื่อได้คะแนนครบแล้วรวมคะแนนแต่ล่ะคน และตัดเกรด ตามเกณฑ์ที่กำหนด

# %%
def grade(score):
  if score>=0 and score<= 100:
    if score>=80: print ('A')
    elif score>=75 and score <= 79: print ('B+')
    elif score>=70 and score <= 74: print ('B')
    elif score>=65 and score <=69: print ('C+')
    elif score>=60 and score <=64 : print ('C')
    elif score>=55 and score <=59: print ('D+')
    elif score>=50 and score <=54: print ('D')
    else: print('F')
  else:
    print('error')

# %%
input
# Out:
#   File "<ipython-input-41-4c0dc0edcef7>", line 1
#     input =
#            ^
# SyntaxError: invalid syntax

# %%
for score_1 in input:
  grade(score_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-faa7c6cd22ba> in <module>()
# ----> 1 for score_1 in input:
#       2   grade(score_1)
#
# TypeError: 'method' object is not iterable
